# %%
#importer les librairies
import numpy
from matplotlib import pyplot

# %%
#créer les données
from sklearn.datasets import make_blobs
X,y = make_blobs(centers=2, cluster_std = 0.5, center_box=(-1.0, 1.0))

# %%
#afficher les données
colors = numpy.array([x for x in "bgrcmyk"])
pyplot.scatter(X[:, 0], X[:, 1], color=colors[y].tolist(), s=10)
pyplot.show()

# %%
#importer le modèle
from sklearn.linear_model import Perceptron

# %%
model = Perceptron(max_iter=10, verbose = 1, eta0 = 1)

# %%
#entraîner le modèle
model.fit(X,y)
print('W = {}, b ={}'.format(model.coef_, model.intercept_))
# Out:
# -- Epoch 1
# Norm: 2.59, NNZs: 2, Bias: 0.000000, T: 100, Avg. loss: 0.358222
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 1.65, NNZs: 2, Bias: 1.000000, T: 200, Avg. loss: 0.354942
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.92, NNZs: 2, Bias: 2.000000, T: 300, Avg. loss: 0.364628
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 2.70, NNZs: 2, Bias: 0.000000, T: 400, Avg. loss: 0.368467
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 2.26, NNZs: 2, Bias: 0.000000, T: 500, Avg. loss: 0.388470
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 1.76, NNZs: 2, Bias: 1.000000, T: 600, Avg. loss: 0.404285
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 2.55, NNZs: 2, Bias: 1.000000, T: 700, Avg. loss: 0.383797
# Total training time: 0.00 seconds.
# Convergence after 7 epochs took 0.00 seconds
# W = [[ 2.37499415 -0.93114533]], b =[1.]

# %%
# Créer  un  mesh
h  =  .02 #  Espacement  du  mesh
x_min,  x_max  =  X[:,  0].min()*1.1,  X[:,  0].max()*1.1
y_min,  y_max  =  X[:,  1].min()*1.1,  X[:,  1].max()*1.1
xx,  yy  =  numpy.meshgrid(numpy.arange(x_min,  x_max,  h), numpy.arange(y_min,  y_max,  h))

# %%
Y  =  model.predict(numpy.c_[xx.ravel(),  yy.ravel()])

#afficher les frontières
Y  =  Y.reshape(xx.shape)
pyplot.contourf(xx,  yy,  Y,  cmap=pyplot.cm.Paired,  alpha=0.8)
pyplot.scatter(X[:, 0],  X[:,1],  cmap=pyplot.cm.Paired, color=colors[y].tolist())
pyplot.xlim(xx.min(),  xx.max())
pyplot.ylim(yy.min(),  yy.max())
pyplot.show()
